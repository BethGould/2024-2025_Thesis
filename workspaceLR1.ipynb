# %% [markdown]
# I will be varying $\mu$ and $\Psi^\prime$ as my main variations, $dk$ and $B$ are secondary. $R$ and $A_0$ are fixed. $k0$ is fixed for now, varied later. I may need to set the endpoint of integration above where it is to get a good sample of period estimates for averaging, dependent on the parameters.

# %%
#--LIBRARIES--------
import eelib
from eelib import pi
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
dk = 0.5
R  = 1.0
B  = 0.5
mu = 1.0e-6

#n = 10000 # ~100000 = 12 hrs
#n_dk = 2
#n_k0 = 2
n_B = 4
n_g = 11
n_m = 5

b_r  = (0.7, 1.0) # B here is B*R, since varying R will alter k, which I don't want
dk_r = (0.1, 0.9)
mu_r = (-7.5, -5.5) #1.0e-8 to 1.0e-5

#k0_r #later ....

pr = 1000
n = 20

num_l = [n_m, n_B, n_g]

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_slow_osc(R, B, dk, mu)
gridl.setIntegratorParameters(solve_mu_0=False, n = pr)

gridl.makeGridPoints(mu=mu_r, B=b_r, num = num_l)
gridl.gridSlowOsc()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 16
# mu: 0, dk: 0, Time: 0.0
# 3.5973719216511086e-07 9.280753810075631e-07 2.0918345110915357
# 3.2275959314424444e-07 9.280753810075631e-07 2.0921501760888717
# 9.532534262611859e-08 8.905738323219651e-07 2.0936904554160414
# 1.3269717367785088e-07 8.905738323219651e-07 2.0939265886110565
# 2.7962824507015874e-07 7.184747899383162e-07 2.0923281846950785
# 2.510280586590561e-07 7.184747899383162e-07 2.0921223020478372
# 7.438183129137084e-08 6.957924797586378e-07 2.094878370242031
# 2.798253610843705e-07 6.957924797586378e-07 2.0950287434071053
# mu: 1, dk: 0, Time: 1209.6264548301697
# 3.5973719216511086e-07 1.1450545018320715e-06 2.0927590903130797
# 3.2275959314424444e-07 1.1450545018320715e-06 2.092707983835662
# 9.532534262611859e-08 7.535514873149746e-07 2.096319815588157
# 1.3269717367785088e-07 7.535514873149746e-07 2.095967505875297
# 2.7962824507015874e-07 8.419921866630033e-07 2.0928350714847936
# 2.510280586590561e-07 8.419921866630033e-07 2.092967086221397
# 7.438183129137084e-08 6.092404957323888e-07 2.0962338725909766
# 2.798253610843705e-07 6.092404957323888e-07 2.0964104209084256
# Done grid build:  2316.901796102524

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid010', 'ab')
pickle.dump(gridl, file)
file.close()
