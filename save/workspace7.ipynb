# %%
#--LIBRARIES--------

#numerics
import numpy as np
import eelib

#--CODE--

# set parameters
# note that k, B, and R are percents here, mu is not as its scale is unknown
k = 0.5
R = 1.0
B = 0.5
mu = 1.0e-7

n_g = 2


pr = 200
n = 2



loopl = eelib.deriv_grid(R, B, k, mu, grid_size=n_g)
loopl.derivGrid()


# --- PLOTTING FOR GRIDS ---
for i in range(n_g):
    for j in range(n_g):
        loopl.plot_abs(i,j,k,R,B,mu,n)
# Out:
# Begin grid build:  0.0
# Plot Code: ['er', '0r', '0x', 'em'] 35
# i =  0 of  1 time:  0.0
# 2.8606644256966744e-06 1.2725131375150335e-06
# Done, i, j =  0 0 time:  386.91846346855164
# 2.8606644256966744e-06 1.2725131375150335e-06
# Done, i, j =  0 1 time:  756.3027081489563
# i =  1 of  1 time:  756.3027081489563
# 8.182476636119175e-07 1.2725131375150335e-06
# Done, i, j =  1 0 time:  1151.4744110107422
# 8.182476636119175e-07 1.2725131375150335e-06
# Done, i, j =  1 1 time:  1522.6329004764557
# Done grid build:  1522.6329004764557
