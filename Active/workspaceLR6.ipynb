# %% [markdown]
# # slow oscillations vs mu, right of period boundaries

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.90009091
B  = 0.5
mu = 1.5e-8

ddr = 0.000001
R0 = 0.9
Rm = 1e-6
kk = (k0+dk/Rm/2)
rem = kk*R0*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
R_arr = [R0-dR0+mult, R0-dR0+5*mult/4, R0-dR0+3*mult/2, R0-dR0+7*mult/4, 0.90009091]

n_g = 100
n_r = 4

r_r = (R0-dR0+mult+ddr, R0-dR0+7*mult/4+ddr)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(mu = mu_r, B = b_r, R = r_r, num = [n_g, n_g, n_r])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 40000
# mu: 0, dk: 0, Time: 0.0
# mu: 1, dk: 0, Time: 1389.7670426368713
# mu: 2, dk: 0, Time: 2711.3760697841644
# mu: 3, dk: 0, Time: 3948.6283752918243
# mu: 4, dk: 0, Time: 5142.899296045303
# mu: 5, dk: 0, Time: 6358.887290239334
# mu: 6, dk: 0, Time: 7566.438357114792
# mu: 7, dk: 0, Time: 8818.791830539703
# mu: 8, dk: 0, Time: 10043.974087953568
# mu: 9, dk: 0, Time: 11248.519958019257
# mu: 10, dk: 0, Time: 12463.042927980423
# mu: 11, dk: 0, Time: 13671.928917169571
# mu: 12, dk: 0, Time: 14865.666649103165
# mu: 13, dk: 0, Time: 16098.242002725601
# mu: 14, dk: 0, Time: 17323.293622493744
# mu: 15, dk: 0, Time: 18527.42577624321
# mu: 16, dk: 0, Time: 19734.100890159607
# mu: 17, dk: 0, Time: 20940.929467201233
# mu: 18, dk: 0, Time: 22106.643812656403
# mu: 19, dk: 0, Time: 23249.075226306915
# mu: 20, dk: 0, Time: 24376.29844737053
# mu: 21, dk: 0, Time: 25485.93292450905
# mu: 22, dk: 0, Time: 26619.22747540474
# mu: 23, dk: 0, Time: 27734.345990657806
# mu: 24, dk: 0, Time: 28857.740026712418
# mu: 25, dk: 0, Time: 29951.50865292549
# mu: 26, dk: 0, Time: 31089.634445905685
# mu: 27, dk: 0, Time: 32231.709844827652
# mu: 28, dk: 0, Time: 33345.02597093582
# mu: 29, dk: 0, Time: 34484.69913864136
# mu: 30, dk: 0, Time: 35626.31184768677
# mu: 31, dk: 0, Time: 36774.2379822731
# mu: 32, dk: 0, Time: 37843.83291602135
# mu: 33, dk: 0, Time: 38802.72546386719
# mu: 91, dk: 0, Time: 93767.53944897652
# mu: 92, dk: 0, Time: 94663.79557156563
# mu: 93, dk: 0, Time: 95560.06399607658
# mu: 94, dk: 0, Time: 96473.19669294357
# mu: 95, dk: 0, Time: 97422.94065237045
# mu: 96, dk: 0, Time: 98371.80917596817
# mu: 97, dk: 0, Time: 99327.59360790253
# mu: 98, dk: 0, Time: 100276.26483821869
# mu: 99, dk: 0, Time: 101258.97274661064
# Done grid build:  102240.91850185394

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid054', 'ab')
pickle.dump(gridl, file)
file.close()

# %% [markdown]
# # Large R dependence period boundary

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.9
B  = 0.5
mu = 1.5e-8

ddr = 0.00000001
Rm = 1e-6
Rmax = 1.0
Rmin = 0.57

kk = (k0+dk/Rm/2)
rem = kk*Rmax*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
Rr = -dR0+mult+ddr

n_g = 20
n_r = 515

r_r = (Rmax - dR0-ddr - 5150*mult, Rmax-dR0-ddr)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
#mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(B = b_r, R = r_r, num = [n_g, n_r])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 10300
# mu: 0, dk: 0, Time: 0.0
# Done grid build:  19939.95144343376

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid058', 'ab')
pickle.dump(gridl, file)
file.close()

# %% [markdown]
# # Large R dependence quarter boundary

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.9
B  = 0.5
mu = 1.5e-8

ddr = 0.00000001
Rm = 1e-6
Rmax = 1.0
Rmin = 0.57

kk = (k0+dk/Rm/2)
rem = kk*Rmax*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
Rr = -dR0+mult+ddr

n_g = 20
n_r = 515

r_r = (Rmax - dR0-ddr - 5150*mult+mult/4, Rmax-dR0-ddr+mult/4)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
#mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(B = b_r, R = r_r, num = [n_g, n_r])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 10300
# mu: 0, dk: 0, Time: 0.0
# Done grid build:  19842.61245059967

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid063', 'ab')
pickle.dump(gridl, file)
file.close()

# %% [markdown]
# # Large R dependence half period boundary

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.9
B  = 0.5
mu = 1.5e-8

ddr = 0.00000001
Rm = 1e-6
Rmax = 1.0
Rmin = 0.57

kk = (k0+dk/Rm/2)
rem = kk*Rmax*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
Rr = -dR0+mult+ddr

n_g = 20
n_r = 515

r_r = (Rmax - dR0-ddr - 5150*mult+mult/2, Rmax-dR0-ddr+mult/2)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
#mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(B = b_r, R = r_r, num = [n_g, n_r])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 10300
# mu: 0, dk: 0, Time: 0.0
# Done grid build:  19971.91048669815

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid068', 'ab')
pickle.dump(gridl, file)
file.close()

# %% [markdown]
# # Large R dependence 3/4 period boundary

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.9
B  = 0.5
mu = 1.5e-8

ddr = 0.00000001
Rm = 1e-6
Rmax = 1.0
Rmin = 0.57

kk = (k0+dk/Rm/2)
rem = kk*Rmax*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
Rr = -dR0+mult+ddr

n_g = 20
n_r = 515

r_r = (Rmax - dR0-ddr - 5150*mult+3*mult/4, Rmax-dR0-ddr+3*mult/4)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
#mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(B = b_r, R = r_r, num = [n_g, n_r])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 10300
# mu: 0, dk: 0, Time: 0.0
# Done grid build:  20163.36883187294

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid073', 'ab')
pickle.dump(gridl, file)
file.close()
