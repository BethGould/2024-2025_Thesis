# %% [markdown]
# # slow oscillations vs mu, left of period boundaries

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.90009091
B  = 0.5
mu = 1.5e-8

ddr = -0.000001
R0 = 0.9
Rm = 1e-6
kk = (k0+dk/Rm/2)
rem = kk*R0*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
R_arr = [R0-dR0+mult, R0-dR0+5*mult/4, R0-dR0+3*mult/2, R0-dR0+7*mult/4, 0.90009091]

n_g = 100
n_r = 4

r_r = (R0-dR0+mult+ddr, R0-dR0+7*mult/4+ddr)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(mu = mu_r, B = b_r, R = r_r, num = [n_g, n_g, n_r])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 40000
# mu: 0, dk: 0, Time: 0.0
# mu: 1, dk: 0, Time: 1139.190283536911
# mu: 2, dk: 0, Time: 2248.1813604831696
# mu: 3, dk: 0, Time: 3280.4340386390686
# mu: 4, dk: 0, Time: 4270.783529281616
# mu: 5, dk: 0, Time: 5278.222662687302
# mu: 6, dk: 0, Time: 6262.744277000427
# mu: 7, dk: 0, Time: 7313.494157075882
# mu: 8, dk: 0, Time: 8364.487413406372
# mu: 9, dk: 0, Time: 9383.256248950958
# mu: 10, dk: 0, Time: 10425.945412874222
# mu: 11, dk: 0, Time: 11487.609532117844
# mu: 12, dk: 0, Time: 12517.722921133041
# mu: 13, dk: 0, Time: 13574.698528528214
# mu: 14, dk: 0, Time: 14602.489327669144
# mu: 15, dk: 0, Time: 15639.22235584259
# mu: 16, dk: 0, Time: 16739.814001321793
# mu: 17, dk: 0, Time: 17765.851194381714
# mu: 18, dk: 0, Time: 18846.23167848587
# mu: 19, dk: 0, Time: 19885.345144987106
# mu: 20, dk: 0, Time: 20952.382306337357
# mu: 21, dk: 0, Time: 21955.174796819687
# mu: 22, dk: 0, Time: 22986.89321088791
# mu: 23, dk: 0, Time: 23967.426957130432
# mu: 24, dk: 0, Time: 24955.776240348816
# mu: 25, dk: 0, Time: 25941.731184720993
# mu: 26, dk: 0, Time: 26897.368150949478
# mu: 27, dk: 0, Time: 27898.894752264023
# mu: 28, dk: 0, Time: 28871.774689674377
# mu: 29, dk: 0, Time: 29872.42341852188
# mu: 30, dk: 0, Time: 30864.063522815704
# mu: 31, dk: 0, Time: 31851.050211906433
# mu: 32, dk: 0, Time: 32866.22724032402
# mu: 33, dk: 0, Time: 33897.16404175758
# mu: 91, dk: 0, Time: 84053.12538027763
# mu: 92, dk: 0, Time: 85095.5683825016
# mu: 93, dk: 0, Time: 86174.38552308083
# mu: 94, dk: 0, Time: 87235.40291690826
# mu: 95, dk: 0, Time: 88328.62844109535
# mu: 96, dk: 0, Time: 89458.6694560051
# mu: 97, dk: 0, Time: 90572.68443799019
# mu: 98, dk: 0, Time: 91608.32236790657
# mu: 99, dk: 0, Time: 92576.44517993927
# Done grid build:  93547.85836338997

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid053', 'ab')
pickle.dump(gridl, file)
file.close()

# %% [markdown]
# # Large R dependence period boundary

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.9
B  = 0.5
mu = 1.5e-8

ddr = 0.00000001
Rm = 1e-6
Rmax = 1.0
Rmin = 0.57

kk = (k0+dk/Rm/2)
rem = kk*Rmax*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
Rr = -dR0+mult+ddr

n_g = 20
n_r = 515

r_r = (Rmax - dR0+ddr - 5150*mult, Rmax-dR0+ddr)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
#mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(B = b_r, R = r_r, num = [n_g, n_r])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 10300
# mu: 0, dk: 0, Time: 0.0
# Done grid build:  20025.33067059517

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid057', 'ab')
pickle.dump(gridl, file)
file.close()

# %% [markdown]
# # Large R dependence quarter boundary

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.9
B  = 0.5
mu = 1.5e-8

ddr = 0.00000001
Rm = 1e-6
Rmax = 1.0
Rmin = 0.57

kk = (k0+dk/Rm/2)
rem = kk*Rmax*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
Rr = -dR0+mult+ddr

n_g = 20
n_r = 515

r_r = (Rmax - dR0+ddr - 5150*mult+mult/4, Rmax-dR0+ddr+mult/4)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
#mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(B = b_r, R = r_r, num = [n_g, n_r])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 10300
# mu: 0, dk: 0, Time: 0.0009949207305908203
# Done grid build:  19869.448752880096

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid062', 'ab')
pickle.dump(gridl, file)
file.close()

# %% [markdown]
# # Large R dependence half period boundary

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.9
B  = 0.5
mu = 1.5e-8

ddr = 0.00000001
Rm = 1e-6
Rmax = 1.0
Rmin = 0.57

kk = (k0+dk/Rm/2)
rem = kk*Rmax*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
Rr = -dR0+mult+ddr

n_g = 20
n_r = 515

r_r = (Rmax - dR0+ddr - 5150*mult+mult/2, Rmax-dR0+ddr+mult/2)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
#mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(B = b_r, R = r_r, num = [n_g, n_r])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 10300
# mu: 0, dk: 0, Time: 0.0
# Done grid build:  20001.41367149353

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid067', 'ab')
pickle.dump(gridl, file)
file.close()

# %% [markdown]
# # Large R dependence 3/4 period boundary

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.9
B  = 0.5
mu = 1.5e-8

ddr = 0.00000001
Rm = 1e-6
Rmax = 1.0
Rmin = 0.57

kk = (k0+dk/Rm/2)
rem = kk*Rmax*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
Rr = -dR0+mult+ddr

n_g = 20
n_r = 515

r_r = (Rmax - dR0+ddr - 5150*mult+3*mult/4, Rmax-dR0+ddr+3*mult/4)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
#mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(B = b_r, R = r_r, num = [n_g, n_r])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 10300
# mu: 0, dk: 0, Time: 0.0
# Done grid build:  19850.515198469162

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid072', 'ab')
pickle.dump(gridl, file)
file.close()
