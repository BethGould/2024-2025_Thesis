# %% [markdown]
# # slow oscillations vs mu, node

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.90009091
B  = 0.5
mu = 1.5e-8

R0 = 0.9
Rm = 1e-6
kk = (k0+dk/Rm/2)
rem = kk*R0*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
R_arr = [R0-dR0+mult, R0-dR0+5*mult/4, R0-dR0+3*mult/2, R0-dR0+7*mult/4, 0.90009091]

n_g = 100
n_r = 4

r_r = (R0-dR0+mult, R0-dR0+7*mult/4)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(mu = mu_r, B = b_r, num = [n_g, n_g])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 10000
# mu: 0, dk: 0, Time: 0.0010068416595458984
# mu: 1, dk: 0, Time: 199.3528289794922
# mu: 2, dk: 0, Time: 387.86812472343445
# mu: 3, dk: 0, Time: 579.6763806343079
# mu: 4, dk: 0, Time: 790.9013974666595
# mu: 5, dk: 0, Time: 1018.4476461410522
# mu: 6, dk: 0, Time: 1241.0116655826569
# mu: 7, dk: 0, Time: 1446.2034752368927
# mu: 8, dk: 0, Time: 1632.998520374298
# mu: 9, dk: 0, Time: 1835.8192291259766
# mu: 10, dk: 0, Time: 2049.1434273719788
# mu: 11, dk: 0, Time: 2257.2418427467346
# mu: 12, dk: 0, Time: 2454.692595243454
# mu: 13, dk: 0, Time: 2647.491265296936
# mu: 14, dk: 0, Time: 2838.0961759090424
# mu: 15, dk: 0, Time: 3032.5687630176544
# mu: 16, dk: 0, Time: 3226.969519853592
# mu: 17, dk: 0, Time: 3414.956508398056
# mu: 18, dk: 0, Time: 3604.3962848186493
# mu: 19, dk: 0, Time: 3786.093740463257
# mu: 20, dk: 0, Time: 3974.6158723831177
# mu: 21, dk: 0, Time: 4163.070397615433
# ...

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid052', 'ab')
pickle.dump(gridl, file)
file.close()

# %% [markdown]
# # Large R dependence period boundary

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.90009091
B  = 0.5
mu = 1.5e-8

R0 = 0.9
Rm = 1e-6
kk = (k0+dk/Rm/2)
rem = kk*R0*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
R_arr = [R0-dR0+mult, R0-dR0+5*mult/4, R0-dR0+3*mult/2, R0-dR0+7*mult/4, 0.90009091]

n_g = 100
n_r = 4

r_r = (R0-dR0+mult, R0-dR0+7*mult/4)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(mu = mu_r, B = b_r, num = [n_g, n_g])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 10000
# mu: 0, dk: 0, Time: 0.0010068416595458984
# mu: 1, dk: 0, Time: 199.3528289794922
# mu: 2, dk: 0, Time: 387.86812472343445
# mu: 3, dk: 0, Time: 579.6763806343079
# mu: 4, dk: 0, Time: 790.9013974666595
# mu: 5, dk: 0, Time: 1018.4476461410522
# mu: 6, dk: 0, Time: 1241.0116655826569
# mu: 7, dk: 0, Time: 1446.2034752368927
# mu: 8, dk: 0, Time: 1632.998520374298
# mu: 9, dk: 0, Time: 1835.8192291259766
# mu: 10, dk: 0, Time: 2049.1434273719788
# mu: 11, dk: 0, Time: 2257.2418427467346
# mu: 12, dk: 0, Time: 2454.692595243454
# mu: 13, dk: 0, Time: 2647.491265296936
# mu: 14, dk: 0, Time: 2838.0961759090424
# mu: 15, dk: 0, Time: 3032.5687630176544
# mu: 16, dk: 0, Time: 3226.969519853592
# mu: 17, dk: 0, Time: 3414.956508398056
# mu: 18, dk: 0, Time: 3604.3962848186493
# mu: 19, dk: 0, Time: 3786.093740463257
# mu: 20, dk: 0, Time: 3974.6158723831177
# mu: 21, dk: 0, Time: 4163.070397615433
# ...

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid057', 'ab')
pickle.dump(gridl, file)
file.close()

# %% [markdown]
# # Large R dependence quarter boundary

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.90009091
B  = 0.5
mu = 1.5e-8

R0 = 0.9
Rm = 1e-6
kk = (k0+dk/Rm/2)
rem = kk*R0*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
R_arr = [R0-dR0+mult, R0-dR0+5*mult/4, R0-dR0+3*mult/2, R0-dR0+7*mult/4, 0.90009091]

n_g = 100
n_r = 4

r_r = (R0-dR0+mult, R0-dR0+7*mult/4)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(mu = mu_r, B = b_r, num = [n_g, n_g])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 10000
# mu: 0, dk: 0, Time: 0.0010068416595458984
# mu: 1, dk: 0, Time: 199.3528289794922
# mu: 2, dk: 0, Time: 387.86812472343445
# mu: 3, dk: 0, Time: 579.6763806343079
# mu: 4, dk: 0, Time: 790.9013974666595
# mu: 5, dk: 0, Time: 1018.4476461410522
# mu: 6, dk: 0, Time: 1241.0116655826569
# mu: 7, dk: 0, Time: 1446.2034752368927
# mu: 8, dk: 0, Time: 1632.998520374298
# mu: 9, dk: 0, Time: 1835.8192291259766
# mu: 10, dk: 0, Time: 2049.1434273719788
# mu: 11, dk: 0, Time: 2257.2418427467346
# mu: 12, dk: 0, Time: 2454.692595243454
# mu: 13, dk: 0, Time: 2647.491265296936
# mu: 14, dk: 0, Time: 2838.0961759090424
# mu: 15, dk: 0, Time: 3032.5687630176544
# mu: 16, dk: 0, Time: 3226.969519853592
# mu: 17, dk: 0, Time: 3414.956508398056
# mu: 18, dk: 0, Time: 3604.3962848186493
# mu: 19, dk: 0, Time: 3786.093740463257
# mu: 20, dk: 0, Time: 3974.6158723831177
# mu: 21, dk: 0, Time: 4163.070397615433
# ...

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid062', 'ab')
pickle.dump(gridl, file)
file.close()

# %% [markdown]
# # Large R dependence half period boundary

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.90009091
B  = 0.5
mu = 1.5e-8

R0 = 0.9
Rm = 1e-6
kk = (k0+dk/Rm/2)
rem = kk*R0*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
R_arr = [R0-dR0+mult, R0-dR0+5*mult/4, R0-dR0+3*mult/2, R0-dR0+7*mult/4, 0.90009091]

n_g = 100
n_r = 4

r_r = (R0-dR0+mult, R0-dR0+7*mult/4)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(mu = mu_r, B = b_r, num = [n_g, n_g])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 10000
# mu: 0, dk: 0, Time: 0.0010068416595458984
# mu: 1, dk: 0, Time: 199.3528289794922
# mu: 2, dk: 0, Time: 387.86812472343445
# mu: 3, dk: 0, Time: 579.6763806343079
# mu: 4, dk: 0, Time: 790.9013974666595
# mu: 5, dk: 0, Time: 1018.4476461410522
# mu: 6, dk: 0, Time: 1241.0116655826569
# mu: 7, dk: 0, Time: 1446.2034752368927
# mu: 8, dk: 0, Time: 1632.998520374298
# mu: 9, dk: 0, Time: 1835.8192291259766
# mu: 10, dk: 0, Time: 2049.1434273719788
# mu: 11, dk: 0, Time: 2257.2418427467346
# mu: 12, dk: 0, Time: 2454.692595243454
# mu: 13, dk: 0, Time: 2647.491265296936
# mu: 14, dk: 0, Time: 2838.0961759090424
# mu: 15, dk: 0, Time: 3032.5687630176544
# mu: 16, dk: 0, Time: 3226.969519853592
# mu: 17, dk: 0, Time: 3414.956508398056
# mu: 18, dk: 0, Time: 3604.3962848186493
# mu: 19, dk: 0, Time: 3786.093740463257
# mu: 20, dk: 0, Time: 3974.6158723831177
# mu: 21, dk: 0, Time: 4163.070397615433
# ...

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid067', 'ab')
pickle.dump(gridl, file)
file.close()

# %% [markdown]
# # Large R dependence 3/4 period boundary

# %%
#--LIBRARIES--------
import eelib
from eelib import pi, kFAu
import numpy as np
import pickle

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
k0 = kFAu
dk = 0.45
R  = 0.90009091
B  = 0.5
mu = 1.5e-8

R0 = 0.9
Rm = 1e-6
kk = (k0+dk/Rm/2)
rem = kk*R0*Rm%1
mult = 1/Rm/kk 
dR0 = rem * mult
R_arr = [R0-dR0+mult, R0-dR0+5*mult/4, R0-dR0+3*mult/2, R0-dR0+7*mult/4, 0.90009091]

n_g = 100
n_r = 4

r_r = (R0-dR0+mult, R0-dR0+7*mult/4)
b_r  = (0.4, 0.8) # zero in oscillation slightly larger than 0.5
#dk_r = (0, 3)
mu_r = (-9.5, -7.5)

# %%
#--CODE--

#make loop, grid, or system
gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
gridl.makeGridPoints(mu = mu_r, B = b_r, num = [n_g, n_g])
gridl.gridBVP()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 10000
# mu: 0, dk: 0, Time: 0.0010068416595458984
# mu: 1, dk: 0, Time: 199.3528289794922
# mu: 2, dk: 0, Time: 387.86812472343445
# mu: 3, dk: 0, Time: 579.6763806343079
# mu: 4, dk: 0, Time: 790.9013974666595
# mu: 5, dk: 0, Time: 1018.4476461410522
# mu: 6, dk: 0, Time: 1241.0116655826569
# mu: 7, dk: 0, Time: 1446.2034752368927
# mu: 8, dk: 0, Time: 1632.998520374298
# mu: 9, dk: 0, Time: 1835.8192291259766
# mu: 10, dk: 0, Time: 2049.1434273719788
# mu: 11, dk: 0, Time: 2257.2418427467346
# mu: 12, dk: 0, Time: 2454.692595243454
# mu: 13, dk: 0, Time: 2647.491265296936
# mu: 14, dk: 0, Time: 2838.0961759090424
# mu: 15, dk: 0, Time: 3032.5687630176544
# mu: 16, dk: 0, Time: 3226.969519853592
# mu: 17, dk: 0, Time: 3414.956508398056
# mu: 18, dk: 0, Time: 3604.3962848186493
# mu: 19, dk: 0, Time: 3786.093740463257
# mu: 20, dk: 0, Time: 3974.6158723831177
# mu: 21, dk: 0, Time: 4163.070397615433
# ...

# %%
# since this takes a while to run and is used for a while, it is best to save a copy of the data
file = open('grid072', 'ab')
pickle.dump(gridl, file)
file.close()
