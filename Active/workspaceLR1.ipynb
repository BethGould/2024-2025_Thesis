# %%
#--LIBRARIES--------
import eelib
from eelib import pi
import numpy as np
import pickle

# %% [markdown]
# # Run 1

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
dk = 0.45
R  = 1.0
B  = 0.5

n_g = 1000
n_mu = 20

r_r = (0.57, 1.0)
b_r  = (0.11, 1.0)
dk_r = (0.1, 0.9)
mu_r = (5e-10, 5e-8)

#k0_r #later ....

# %%
# find random mu values
rng = np.random.default_rng()
mu_arr = []
for i in range(n_mu):
    mu_arr.append(mu_r[0] + rng.random()*(mu_r[1]-mu_r[0]))

# %%
# for each random mu value, make a mc object with parameters
for i, mu in enumerate(mu_arr):
    gridl = eelib.grid_bvp.grid_BVP(R, B, dk, mu)
    gridl.makeMCPoints(dk = dk_r, B = b_r, R = r_r, num = n_g)
    gridl.mcBVP()

    filename = "grid_"+str(i)
    file = open(filename, 'ab')
    pickle.dump(gridl, file)
    file.close()
# Out:
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  5981.005553245544
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  5813.821016788483
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  5673.915572881699
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  5480.016997337341
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  5101.056717157364
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  5084.521309375763
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  4950.617304325104
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  4257.886040210724
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  4232.956162214279
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  4185.619177103043
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  4129.784994840622
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  4137.182596683502
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  4127.343223571777
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  4113.682480335236
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  4075.8055624961853
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  4107.099161624908
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  4074.5126659870148
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  4118.112364530563
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  4125.420998573303
# Begin grid build:  0.0
# Number of periods to calculate: 1000
# Done grid build:  4122.929434537888
