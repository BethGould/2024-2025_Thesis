# %%
#--LIBRARIES--------
import eelib
from eelib import pi
import numpy as np
import pickle

# %% [markdown]
# # Run 1

# %%
#--PARAMETERS--------

# note that k, B, and R are percents here, mu is not as its scale is unknown
dk = 0.45
R  = 1.0
B  = 0.5

n_g = 5000
n_mu = 50

r_r = (0.57, 1.0)
b_r  = (0.11, 1.0)
dk_r = (0.1, 0.9)
mu_r = (-10, -7.5)

#k0_r #later ....

# %%
# find random mu values
rng = np.random.default_rng()
mu_arr = []
for i in range(n_mu):
    mu_arr.append(np.power(10, mu_r[0] + rng.random()*(mu_r[1]-mu_r[0])))

# %%
mu_arr.sort()
print(mu_arr)
# Out:
# [1.0596408029834575e-10, 1.0895639039434064e-10, 1.3315642021319997e-10, 1.800777716321132e-10, 2.250669644969313e-10, 3.407612379929853e-10, 3.8432004134673704e-10, 4.50072027412242e-10, 4.631645653710462e-10, 5.235480952380177e-10, 6.527422303852824e-10, 8.015724027248693e-10, 1.0198799179103712e-09, 1.0239292515878666e-09, 1.1750279503005306e-09, 1.2191813328089346e-09, 1.249103851323428e-09, 1.3752857630344766e-09, 1.3817884046400528e-09, 1.3980316969876887e-09, 1.5218620602105599e-09, 1.6183460249695733e-09, 1.8079420495706673e-09, 1.8711961193222707e-09, 2.22381846465412e-09, 2.3534367230900597e-09, 3.2081433807029156e-09, 3.253182116999754e-09, 3.406214787047447e-09, 3.8243620556045875e-09, 4.138120595725339e-09, 4.820025720223975e-09, 4.841628347519589e-09, 5.144259682019215e-09, 5.718751385894267e-09, 6.926599322213435e-09, 7.757628729383528e-09, 1.069974794712392e-08, 1.1175901703990409e-08, 1.1746835728717256e-08, 1.2203228424340349e-08, 1.2425216841666995e-08, 1.3656226947157199e-08, 1.4858905719122762e-08, 1.5280134734284327e-08, 1.743900550095013e-08, 1.7546194722407123e-08, 2.2737960946313886e-08, 2.9503638478225066e-08, 3.0943829283991483e-08]

# %%
# for each random mu value, make a mc object with parameters
for i, mu in enumerate(mu_arr):
    #mu = mu_arr[i]
    print(i, mu)
    gridl = eelib.grid_bvp.grid_BVP(R=R, B=B, dk=dk, mu=mu)
    gridl.makeMCPoints(dk = dk_r, B = b_r, R = r_r, num = n_g)
    gridl.mcBVP()
    
    filename = "gridz_"+str(i)
    file = open(filename, 'ab')
    pickle.dump(gridl, file)
    file.close()

    #print(gridl)
# Out:
# 0 1.0596408029834575e-10
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  5784.027670383453
# 1 1.0895639039434064e-10
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  5850.414275407791
# 2 1.3315642021319997e-10
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  6326.925171375275
# 3 1.800777716321132e-10
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  6338.869136333466
# 4 2.250669644969313e-10
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  6337.777278661728
# 5 3.407612379929853e-10
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  6545.646413326263
# 6 3.8432004134673704e-10
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  6587.486640453339
# 7 4.50072027412242e-10
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  6666.499622106552
# 8 4.631645653710462e-10
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  6722.863358259201
# 9 5.235480952380177e-10
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  6835.869575500488
# 10 6.527422303852824e-10
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  6818.850819826126
# 11 8.015724027248693e-10
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  6983.866455554962
# 12 1.0198799179103712e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  7151.193463087082
# 13 1.0239292515878666e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  7101.254786491394
# 14 1.1750279503005306e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  7156.493858337402
# 15 1.2191813328089346e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  7210.675947666168
# 16 1.249103851323428e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  7269.522460460663
# 17 1.3752857630344766e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  7448.666056394577
# 18 1.3817884046400528e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  7761.2902183532715
# 19 1.3980316969876887e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  7591.473790407181
# 20 1.5218620602105599e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  7826.764142274857
# 21 1.6183460249695733e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  7795.522756814957
# 22 1.8079420495706673e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  7878.093712091446
# 23 1.8711961193222707e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  7897.633274793625
# 24 2.22381846465412e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  7983.447988986969
# 25 2.3534367230900597e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  7889.3056671619415
# 26 3.2081433807029156e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8271.50828576088
# 27 3.253182116999754e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8234.811947345734
# 28 3.406214787047447e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8289.335906028748
# 29 3.8243620556045875e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8273.01883840561
# 30 4.138120595725339e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8448.418703317642
# 31 4.820025720223975e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8604.471009731293
# 32 4.841628347519589e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8598.211339712143
# 33 5.144259682019215e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8631.932756900787
# 34 5.718751385894267e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8849.073570728302
# 35 6.926599322213435e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8427.520382165909
# 36 7.757628729383528e-09
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8633.954094409943
# 37 1.069974794712392e-08
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8807.102627515793
# 38 1.1175901703990409e-08
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8733.117969036102
# 39 1.1746835728717256e-08
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8691.499385118484
# 40 1.2203228424340349e-08
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8747.804191589355
# 41 1.2425216841666995e-08
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8778.030557632446
# 42 1.3656226947157199e-08
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8783.972202777863
# 43 1.4858905719122762e-08
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  8933.26210808754
# 44 1.5280134734284327e-08
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  9049.12014055252
# 45 1.743900550095013e-08
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  9077.199272871017
# 46 1.7546194722407123e-08
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  9208.37975859642
# 47 2.2737960946313886e-08
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  9486.933861494064
# 48 2.9503638478225066e-08
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  9864.332042217255
# 49 3.0943829283991483e-08
# Begin grid build:  0.0
# Number of periods to calculate: 5000
# Done grid build:  10100.396339654922

# %%
print(gridl)
# Out:
# Monte Carlo object to measure current:
# mu has points from 2.8681687988635135e-08 to 2.8681687988635135e-08.
# dk has points from 0.10174645139093182 to 0.8997156716698107.
# B has points from 0.11078093086230553 to 0.999734229441263.
# R has points from 0.5711385137234465 to 0.9997752160989797.
# A has points from 1.0 to 1.0.
# k0 has points from 12000000000.0 to 12000000000.0.
# Number of points: 1000
